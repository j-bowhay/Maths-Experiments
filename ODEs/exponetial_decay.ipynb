# %% [markdown]
# \begin{equation}
# y^\prime + y = 0, \quad t \in [0, 3], \quad y(0) = 1.
# \end{equation}

# %%
using ApproxFun, Plots

d = 0..3
D = Derivative(d)
L = D + 1

A = [L; ivp()]
y = \(A, [0, 1], tolerance=1e-6)
# Out:
# Fun(Chebyshev(0 .. 3), [0.367434, -0.438079, 0.150762, -0.0360463, 0.00657706, -0.000968635, 0.000119495, -1.26767e-5, 1.17928e-6, -9.76645e-8  …  1.52131e-12, -1.52131e-12, 1.52131e-12, -1.52131e-12, 1.52131e-12, -1.52131e-12, 1.52131e-12, -1.52131e-12, 1.52131e-12, 1.03972e-10])

# %%
plot(0:0.1:3, y, label="Numerical")
plot!(0:0.1:3, x -> exp(-x), label="Analytical", linestyle=:dash)
